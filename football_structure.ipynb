# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Timothy/Downloads/spi_matches.csv')

# %%
df.head()
# Out:
#          date  league_id                   league           team1  \
# 0  2016-08-12       1843           French Ligue 1          Bastia
# 1  2016-08-12       1843           French Ligue 1       AS Monaco
# 2  2016-08-13       2411  Barclays Premier League       Hull City
# 3  2016-08-13       2411  Barclays Premier League  Crystal Palace
# 4  2016-08-13       2411  Barclays Premier League         Everton
#
#                   team2   spi1   spi2   prob1   prob2  probtie     ...      \
# 0   Paris Saint-Germain  51.16  85.68  0.0463  0.8380   0.1157     ...
# 1              Guingamp  68.85  56.48  0.5714  0.1669   0.2617     ...
# 2        Leicester City  53.57  66.81  0.3459  0.3621   0.2921     ...
# 3  West Bromwich Albion  55.19  58.66  0.4214  0.2939   0.2847     ...
# 4     Tottenham Hotspur  68.02  73.25  0.3910  0.3401   0.2689     ...
#
#    importance1  importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'league_id', 'league', 'team1', 'team2', 'spi1', 'spi2',
#        'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
df1 = df

l = []
for k,v in df1.iterrows():
    
    # Home Team
    sl = []
    for col in v.index:
        if col[-1] != '1' and col[-1] != '2':
            sl.append(v[col])
    for col in v.index:
        if col[-1] == '1':
            sl.append(v[col])
    sl.append('Home Team')
    l.append (sl)
    
    # Away
    sl = []
    for col in v.index:
        if col[-1] != '1' and col[-1] != '2':
            sl.append(v[col])
    for col in v.index:
        if col[-1] == '2':
            sl.append(v[col])
    sl.append('Away Team')
    l.append (sl)

# %%
# Print example of first row
print(l[0])
# Out:
# ['2016-08-12', 1843, 'French Ligue 1', 0.1157, 'Bastia', 51.16, 0.0463, 0.91, 32.4, 0.0, 0.97, 0.43, 0.0, 'Home Team']

# %%
# Specify new columns and transform it to DataFrame
col = ['date','league_id','league','team','spi','prob','probtie','proj_score','importance','score','xg','nsxg','adj','home_away']
transformed_df = pd.DataFrame(l,columns = col )

# Check head of dataframe
transformed_df
# Out:
#              date  league_id                    league    team  \
# 0      2016-08-12       1843            French Ligue 1  0.1157
# 1      2016-08-12       1843            French Ligue 1  0.1157
# 2      2016-08-12       1843            French Ligue 1  0.2617
# 3      2016-08-12       1843            French Ligue 1  0.2617
# 4      2016-08-13       2411   Barclays Premier League  0.2921
# 5      2016-08-13       2411   Barclays Premier League  0.2921
# 6      2016-08-13       2411   Barclays Premier League  0.2847
# 7      2016-08-13       2411   Barclays Premier League  0.2847
# 8      2016-08-13       2411   Barclays Premier League  0.2689
# 9      2016-08-13       2411   Barclays Premier League  0.2689
# 10     2016-08-13       2411   Barclays Premier League  0.2927
# 11     2016-08-13       2411   Barclays Premier League  0.2927
# 12     2016-08-13       2411   Barclays Premier League  0.2854
# 13     2016-08-13       2411   Barclays Premier League  0.2854
# ...

# %%
# Export to csv
transformed_df.to_csv('C:/Users/Timothy/Desktop/trans_football.csv', header = True)
