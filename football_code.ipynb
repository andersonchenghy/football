# %%
import pandas as pd

# %%
df = pd.read_csv('E:/spi_matches.csv')

# %%
df.head()
# Out:
#          date  league_id                   league           team1  \
# 0  12/08/2016       1843           French Ligue 1          Bastia
# 1  12/08/2016       1843           French Ligue 1       AS Monaco
# 2  13/08/2016       2411  Barclays Premier League       Hull City
# 3  13/08/2016       2411  Barclays Premier League  Crystal Palace
# 4  13/08/2016       2411  Barclays Premier League         Everton
#
#                   team2   spi1   spi2   prob1   prob2  probtie     ...      \
# 0   Paris Saint-Germain  51.16  85.68  0.0463  0.8380   0.1157     ...
# 1              Guingamp  68.85  56.48  0.5714  0.1669   0.2617     ...
# 2        Leicester City  53.57  66.81  0.3459  0.3621   0.2921     ...
# 3  West Bromwich Albion  55.19  58.66  0.4214  0.2939   0.2847     ...
# 4     Tottenham Hotspur  68.02  73.25  0.3910  0.3401   0.2689     ...
#
#    importance1  importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  \
# 0         32.4         67.7     0.0     1.0  0.97  0.63   0.43   0.45
# 1         53.7         22.9     2.0     2.0  2.45  0.77   1.75   0.42
# 2         38.1         22.2     2.0     1.0  0.85  2.77   0.17   1.25
# 3         43.6         34.6     0.0     1.0  1.11  0.68   0.84   1.60
# 4         31.9         48.0     1.0     1.0  0.73  1.11   0.88   1.81
#
#    adj_score1  adj_score2
# 0        0.00        1.05
# 1        2.10        2.10
# 2        2.10        1.05
# 3        0.00        1.05
# 4        1.05        1.05
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['date', 'league_id', 'league', 'team1', 'team2', 'spi1', 'spi2',
#        'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
df1 = df

l = []
for k,v in df1.iterrows():
    
    # Home Team
    sl = []
    for col in v.index:
        if col[-1] != '1' and col[-1] != '2':
            sl.append(v[col])
    for col in v.index:
        if col[-1] == '1':
            sl.append(v[col])
    sl.append('Home Team')
    l.append (sl)
    
    # Away
    sl = []
    for col in v.index:
        if col[-1] != '1' and col[-1] != '2':
            sl.append(v[col])
    for col in v.index:
        if col[-1] == '2':
            sl.append(v[col])
    sl.append('Away Team')
    l.append (sl)

# %%
# Print example of first row
print(l[0])
# Out:
# ['12/08/2016', 1843, 'French Ligue 1', 0.1157, 'Bastia', 51.16, 0.0463, 0.91, 32.4, 0.0, 0.97, 0.43, 0.0, 'Home Team']

# %%
# Specify new columns and transform it to DataFrame
col = ['date','league_id','league','team','spi','prob','probtie','proj_score','importance','score','xg','nsxg','adj','home_away']
transformed_df = pd.DataFrame(l,columns = col )

# Check head of dataframe
transformed_df
# Out:
#              date  league_id                    league    team  \
# 0      12/08/2016       1843            French Ligue 1  0.1157
# 1      12/08/2016       1843            French Ligue 1  0.1157
# 2      12/08/2016       1843            French Ligue 1  0.2617
# 3      12/08/2016       1843            French Ligue 1  0.2617
# 4      13/08/2016       2411   Barclays Premier League  0.2921
# 5      13/08/2016       2411   Barclays Premier League  0.2921
# 6      13/08/2016       2411   Barclays Premier League  0.2847
# 7      13/08/2016       2411   Barclays Premier League  0.2847
# 8      13/08/2016       2411   Barclays Premier League  0.2689
# 3                  Guingamp  56.48   0.1669        0.86        22.9    2.0
# 4                 Hull City  53.57   0.3459        1.16        38.1    2.0
# 5            Leicester City  66.81   0.3621        1.24        22.2    1.0
# 6            Crystal Palace  55.19   0.4214        1.35        43.6    0.0
# 7      West Bromwich Albion  58.66   0.2939        1.14        34.6    1.0
# 8                   Everton  68.02   0.3910        1.47        31.9    1.0
# 9         Tottenham Hotspur  73.25   0.3401        1.38        48.0    1.0
# 10            Middlesbrough  56.32   0.4380        1.30        33.9    1.0
# 11               Stoke City  60.35   0.2692        1.01        32.5    1.0
# 12                  Burnley  58.98   0.4482        1.37        36.5    0.0
# 13             Swansea City  59.74   0.2663        1.05        29.1    1.0
# 14              Southampton  69.49   0.5759        1.91        34.1    1.0
# 15                  Watford  59.33   0.1874        1.05        30.7    1.0
# 16                 Bordeaux  62.01   0.4232        1.39        37.9    3.0
# 17               St Etienne  64.92   0.2764        1.14        44.2    2.0
# 18          Manchester City  86.42   0.8152        2.69        73.0    2.0
# 19               Sunderland  53.64   0.0525        0.48        27.0    1.0
# 20                     Metz  54.34   0.3444        1.18        26.9    3.0
# 21                    Lille  66.10   0.3479        1.30        48.7    2.0
# 22              Montpellier  58.82   0.4939        1.51        22.5    1.0
# 23                   Angers  53.10   0.2109        0.89        27.7    0.0
# 24                     Caen  55.00   0.4737        1.62        28.1    3.0
# 25                  Lorient  47.64   0.2401        1.11        28.5    2.0
# 26                Dijon FCO  55.00   0.4471        1.40        29.2    0.0
# 27                   Nantes  54.90   0.2490        1.01        25.6    1.0
# 28          AFC Bournemouth  61.57   0.2111        1.15        27.9    1.0
# 29        Manchester United  80.49   0.5461        1.78        58.0    3.0
# ...                     ...    ...      ...         ...         ...    ...
# 42222                 Elche  24.83   0.2603        1.02         NaN    NaN
# 42223  Deportivo La Coru??a  43.86   0.4539        1.44         NaN    NaN
# 42224                 Cadiz  42.97   0.6066        1.79         NaN    NaN
# 42225        Extremadura UD  30.71   0.1489        0.75         NaN    NaN
# 42226           Real Oviedo  29.30   0.5244        1.44         NaN    NaN
# 42227      Rayo Majadahonda  23.02   0.1858        0.74         NaN    NaN
# 42228                  Lugo  26.02   0.4415        1.13         NaN    NaN
# 42229              Tenerife  26.78   0.2220        0.71         NaN    NaN
# 42230              Numancia  28.81   0.4073        1.51         NaN    NaN
# 42231            Las Palmas  34.20   0.3226        1.31         NaN    NaN
# 42232               Osasuna  35.88   0.5276        1.57         NaN    NaN
# 42233           Real Oviedo  29.30   0.1989        0.85         NaN    NaN
# 42234        Extremadura UD  30.71   0.4124        1.42         NaN    NaN
# 42235              Mallorca  33.85   0.3062        1.19         NaN    NaN
# 42236              Tenerife  26.78   0.4534        1.38         NaN    NaN
# 42237         Real Zaragoza  27.19   0.2527        0.96         NaN    NaN
# 42238  Deportivo La Coru??a  43.86   0.6915        2.16         NaN    NaN
# 42239               Cordoba  24.01   0.1089        0.72         NaN    NaN
# 42240      Rayo Majadahonda  23.02   0.4559        1.19         NaN    NaN
# 42241         Reus Deportiu  21.99   0.2172        0.72         NaN    NaN
# 42242       Sporting Gij??n  33.94   0.3555        1.02         NaN    NaN
# 42243                 Cadiz  42.97   0.3092        0.93         NaN    NaN
# 42244  Gimn??stic Tarragona  17.34   0.3272        0.90         NaN    NaN
# 42245                  Lugo  26.02   0.3193        0.89         NaN    NaN
# 42246               M??laga  38.68   0.6127        1.66         NaN    NaN
# 42247                 Elche  24.83   0.1306        0.61         NaN    NaN
# 42248               Almeria  33.39   0.4017        1.18         NaN    NaN
# 42249              Albacete  38.10   0.2814        0.94         NaN    NaN
# 42250               Granada  39.64   0.5255        1.22         NaN    NaN
# 42251           AD Alcorcon  30.90   0.1467        0.50         NaN    NaN
#
#          xg  nsxg   adj  home_away
# 0      0.97  0.43  0.00  Home Team
# 1      0.63  0.45  1.05  Away Team
# 2      2.45  1.75  2.10  Home Team
# 3      0.77  0.42  2.10  Away Team
# 4      0.85  0.17  2.10  Home Team
# 5      2.77  1.25  1.05  Away Team
# 6      1.11  0.84  0.00  Home Team
# 7      0.68  1.60  1.05  Away Team
# 8      0.73  0.88  1.05  Home Team
# 9      1.11  1.81  1.05  Away Team
# 10     1.40  1.13  1.05  Home Team
# 11     0.55  1.06  1.05  Away Team
# 12     1.24  1.71  0.00  Home Team
# 13     1.84  1.56  1.05  Away Team
# 14     1.05  1.52  1.05  Home Team
# 15     0.22  0.41  1.05  Away Team
# 16     1.03  1.10  3.12  Home Team
# 17     1.84  2.26  2.10  Away Team
# 18     2.14  1.81  2.10  Home Team
# 19     1.25  0.92  1.05  Away Team
# 20     2.35  0.68  3.15  Home Team
# 21     1.87  1.26  2.10  Away Team
# 22     0.80  0.58  1.05  Home Team
# 23     0.53  1.28  0.00  Away Team
# 24     2.14  1.88  3.15  Home Team
# 25     2.04  0.91  2.10  Away Team
# 26     0.30  0.81  0.00  Home Team
# 27     1.17  0.87  1.05  Away Team
# 28     0.51  1.11  1.05  Home Team
# 29     2.21  0.88  3.15  Away Team
# ...     ...   ...   ...        ...
# 42222   NaN   NaN   NaN  Home Team
# 42223   NaN   NaN   NaN  Away Team
# 42224   NaN   NaN   NaN  Home Team
# 42225   NaN   NaN   NaN  Away Team
# 42226   NaN   NaN   NaN  Home Team
# 42227   NaN   NaN   NaN  Away Team
# 42228   NaN   NaN   NaN  Home Team
# 42229   NaN   NaN   NaN  Away Team
# 42230   NaN   NaN   NaN  Home Team
# 42231   NaN   NaN   NaN  Away Team
# 42232   NaN   NaN   NaN  Home Team
# 42233   NaN   NaN   NaN  Away Team
# 42234   NaN   NaN   NaN  Home Team
# 42235   NaN   NaN   NaN  Away Team
# 42236   NaN   NaN   NaN  Home Team
# 42237   NaN   NaN   NaN  Away Team
# 42238   NaN   NaN   NaN  Home Team
# 42239   NaN   NaN   NaN  Away Team
# 42240   NaN   NaN   NaN  Home Team
# 42241   NaN   NaN   NaN  Away Team
# 42242   NaN   NaN   NaN  Home Team
# 42243   NaN   NaN   NaN  Away Team
# 42244   NaN   NaN   NaN  Home Team
# 42245   NaN   NaN   NaN  Away Team
# 42246   NaN   NaN   NaN  Home Team
# 42247   NaN   NaN   NaN  Away Team
# 42248   NaN   NaN   NaN  Home Team
# 42249   NaN   NaN   NaN  Away Team
# 42250   NaN   NaN   NaN  Home Team
# 42251   NaN   NaN   NaN  Away Team
#
# [42252 rows x 14 columns]

# %%
# Export to csv
transformed_df.to_csv('E:/trans_football.csv', header = True)
